# %%
import numpy as np
import pandas as pd 
from sklearn.preprocessing import StandardScaler

from transformers import BertTokenizer

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import GlobalAveragePooling1D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import GlobalAveragePooling1D
from tensorflow import keras
from tensorflow.keras import layers

# plots and images
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image

#sklearn processing
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split



import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

#configs
max_tokens = 20000
# Out:
# /kaggle/input/feedback-prize-english-language-learning/sample_submission.csv
# /kaggle/input/feedback-prize-english-language-learning/train.csv
# /kaggle/input/feedback-prize-english-language-learning/test.csv

# %%
sample_submission_raw = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/sample_submission.csv')
train_data_raw = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/train.csv')
test_from_comp = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/test.csv')

# %%
train, test = train_test_split(train_data_raw, test_size=0.2, random_state=21) #20% for test
train, val = train_test_split(train, test_size=0.1, random_state=21) # 10% for validation
train

targets=['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']

sc_y = StandardScaler()
train_targets = sc_y.fit_transform(train[targets])
val_targets = sc_y.transform(val[targets])
test_targets = sc_y.transform(test[targets])

train_targets_ds = tf.convert_to_tensor(train_targets)
val_targets_ds = tf.convert_to_tensor(val_targets)
test_targets_ds = tf.convert_to_tensor(test_targets)

train_text_only = tf.convert_to_tensor(train['full_text'])
val_text_only = tf.convert_to_tensor(val['full_text'])
test_text_only = tf.convert_to_tensor(test['full_text'])


## for submission 
all_sc_y = StandardScaler()
all_train_targets = all_sc_y.fit_transform(train_data_raw[targets])
all_train_targets_ds = tf.convert_to_tensor(all_train_targets)
all_train_text_only = tf.convert_to_tensor(train_data_raw['full_text'])

all_test_text_only = tf.convert_to_tensor(test_from_comp['full_text'])

# %%
# text_vectorization = layers.TextVectorization(
#     max_tokens=max_tokens,
#     output_mode="multi_hot"
# )

text_vectorization = layers.TextVectorization(
    ngrams=2,
    max_tokens=max_tokens,
    output_mode="multi_hot",
)

#use the dataset to index the dataset vocab via the adapt method
text_vectorization.adapt(train_text_only)

train_features_ds = text_vectorization(train_text_only)
val_features_ds = text_vectorization(val_text_only)
test_features_ds = text_vectorization(test_text_only)

#for submission
all_train_features_ds = text_vectorization(all_train_text_only)
all_test_features_ds = text_vectorization(all_test_text_only)

# %%
def get_model(max_tokens=max_tokens, hidden_dim=32):
    inputs = keras.Input(shape=(max_tokens,))

    x = layers.Dense(hidden_dim, activation="relu")(inputs)
    x = layers.Dropout(rate=0.5)(x)
    
    x = layers.Dense(hidden_dim, activation="relu")(x)
    x = layers.Dropout(rate=0.5)(x)
    
    x = layers.Dense(hidden_dim, activation="relu")(x)
    x = layers.Dropout(rate=0.5)(x)


    outputs = layers.Dense(6, activation=None)(x)
    
    model = keras.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss="mean_absolute_error",
        metrics=[tf.keras.metrics.RootMeanSquaredError(
                name='root_mean_squared_error', dtype=None
            )]
    )
    return model

#train model and test
model = get_model()
model.summary()

callbacks = [
    keras.callbacks.ModelCheckpoint("binary_2gram.keras", save_best_only=True)
]
hist = model.fit(
    x=train_features_ds,
    y=train_targets_ds,
    validation_data = (
        val_features_ds, val_targets_ds
    ),
    epochs=100,
    callbacks=callbacks
)

model = keras.models.load_model("binary_2gram.keras")
print(f"Test acc: {model.evaluate(test_features_ds, test_targets_ds, 1)}")
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 20000)]           0
# _________________________________________________________________
# dense_20 (Dense)             (None, 32)                640032
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 643,398
# Trainable params: 643,398
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 88/88 [==============================] - 2s 14ms/step - loss: 0.7937 - root_mean_squared_error: 1.0031 - val_loss: 0.8401 - val_root_mean_squared_error: 1.0528
# Epoch 2/100
# 88/88 [==============================] - 1s 6ms/step - loss: 0.7777 - root_mean_squared_error: 0.9934 - val_loss: 0.8279 - val_root_mean_squared_error: 1.0422
# Epoch 3/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7695 - root_mean_squared_error: 0.9886 - val_loss: 0.8258 - val_root_mean_squared_error: 1.0403
# Epoch 4/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7587 - root_mean_squared_error: 0.9764 - val_loss: 0.8281 - val_root_mean_squared_error: 1.0445
# Epoch 5/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7612 - root_mean_squared_error: 0.9818 - val_loss: 0.8297 - val_root_mean_squared_error: 1.0469
# Epoch 6/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7476 - root_mean_squared_error: 0.9683 - val_loss: 0.8222 - val_root_mean_squared_error: 1.0389
# Epoch 7/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7416 - root_mean_squared_error: 0.9618 - val_loss: 0.8271 - val_root_mean_squared_error: 1.0442
# Epoch 8/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7395 - root_mean_squared_error: 0.9591 - val_loss: 0.8258 - val_root_mean_squared_error: 1.0425
# Epoch 9/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7352 - root_mean_squared_error: 0.9545 - val_loss: 0.8215 - val_root_mean_squared_error: 1.0373
# Epoch 10/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7343 - root_mean_squared_error: 0.9527 - val_loss: 0.8261 - val_root_mean_squared_error: 1.0422
# Epoch 11/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7292 - root_mean_squared_error: 0.9489 - val_loss: 0.8288 - val_root_mean_squared_error: 1.0448
# Epoch 12/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7240 - root_mean_squared_error: 0.9523 - val_loss: 0.8287 - val_root_mean_squared_error: 1.0444
# Epoch 13/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7282 - root_mean_squared_error: 0.9463 - val_loss: 0.8263 - val_root_mean_squared_error: 1.0408
# Epoch 14/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7243 - root_mean_squared_error: 0.9425 - val_loss: 0.8237 - val_root_mean_squared_error: 1.0372
# Epoch 15/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7248 - root_mean_squared_error: 0.9431 - val_loss: 0.8251 - val_root_mean_squared_error: 1.0382
# Epoch 16/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7176 - root_mean_squared_error: 0.9311 - val_loss: 0.8258 - val_root_mean_squared_error: 1.0387
# Epoch 17/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7202 - root_mean_squared_error: 0.9353 - val_loss: 0.8255 - val_root_mean_squared_error: 1.0373
# Epoch 18/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7158 - root_mean_squared_error: 0.9302 - val_loss: 0.8252 - val_root_mean_squared_error: 1.0366
# Epoch 19/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7152 - root_mean_squared_error: 0.9287 - val_loss: 0.8261 - val_root_mean_squared_error: 1.0369
# Epoch 20/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7138 - root_mean_squared_error: 0.9253 - val_loss: 0.8257 - val_root_mean_squared_error: 1.0358
# Epoch 21/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7128 - root_mean_squared_error: 0.9230 - val_loss: 0.8241 - val_root_mean_squared_error: 1.0321
# Epoch 22/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7115 - root_mean_squared_error: 0.9252 - val_loss: 0.8275 - val_root_mean_squared_error: 1.0354
# Epoch 23/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7108 - root_mean_squared_error: 0.9187 - val_loss: 0.8252 - val_root_mean_squared_error: 1.0318
# Epoch 24/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7050 - root_mean_squared_error: 0.9105 - val_loss: 0.8272 - val_root_mean_squared_error: 1.0337
# Epoch 25/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7026 - root_mean_squared_error: 0.9073 - val_loss: 0.8265 - val_root_mean_squared_error: 1.0318
# Epoch 26/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7025 - root_mean_squared_error: 0.9090 - val_loss: 0.8228 - val_root_mean_squared_error: 1.0268
# Epoch 27/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6990 - root_mean_squared_error: 0.9014 - val_loss: 0.8309 - val_root_mean_squared_error: 1.0350
# Epoch 28/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7026 - root_mean_squared_error: 0.9065 - val_loss: 0.8324 - val_root_mean_squared_error: 1.0365
# Epoch 29/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6985 - root_mean_squared_error: 0.8980 - val_loss: 0.8324 - val_root_mean_squared_error: 1.0359
# Epoch 30/100
# 88/88 [==============================] - 1s 6ms/step - loss: 0.6920 - root_mean_squared_error: 0.8902 - val_loss: 0.8327 - val_root_mean_squared_error: 1.0359
# Epoch 31/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6851 - root_mean_squared_error: 0.8812 - val_loss: 0.8382 - val_root_mean_squared_error: 1.0419
# Epoch 32/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6869 - root_mean_squared_error: 0.8848 - val_loss: 0.8320 - val_root_mean_squared_error: 1.0343
# Epoch 33/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6860 - root_mean_squared_error: 0.8827 - val_loss: 0.8363 - val_root_mean_squared_error: 1.0378
# Epoch 34/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6788 - root_mean_squared_error: 0.8723 - val_loss: 0.8333 - val_root_mean_squared_error: 1.0328
# Epoch 35/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6805 - root_mean_squared_error: 0.8732 - val_loss: 0.8438 - val_root_mean_squared_error: 1.0422
# Epoch 36/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6710 - root_mean_squared_error: 0.8607 - val_loss: 0.8398 - val_root_mean_squared_error: 1.0386
# Epoch 37/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6755 - root_mean_squared_error: 0.8659 - val_loss: 0.8404 - val_root_mean_squared_error: 1.0380
# Epoch 38/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6669 - root_mean_squared_error: 0.8557 - val_loss: 0.8493 - val_root_mean_squared_error: 1.0466
# Epoch 39/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6655 - root_mean_squared_error: 0.8525 - val_loss: 0.8432 - val_root_mean_squared_error: 1.0398
# Epoch 40/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6649 - root_mean_squared_error: 0.8509 - val_loss: 0.8410 - val_root_mean_squared_error: 1.0377
# Epoch 41/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6627 - root_mean_squared_error: 0.8494 - val_loss: 0.8465 - val_root_mean_squared_error: 1.0440
# Epoch 42/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6545 - root_mean_squared_error: 0.8388 - val_loss: 0.8467 - val_root_mean_squared_error: 1.0451
# Epoch 43/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6601 - root_mean_squared_error: 0.8474 - val_loss: 0.8495 - val_root_mean_squared_error: 1.0493
# Epoch 44/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6514 - root_mean_squared_error: 0.8372 - val_loss: 0.8475 - val_root_mean_squared_error: 1.0484
# Epoch 45/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6494 - root_mean_squared_error: 0.8389 - val_loss: 0.8493 - val_root_mean_squared_error: 1.0500
# Epoch 46/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6484 - root_mean_squared_error: 0.8372 - val_loss: 0.8534 - val_root_mean_squared_error: 1.0554
# Epoch 47/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6460 - root_mean_squared_error: 0.8356 - val_loss: 0.8614 - val_root_mean_squared_error: 1.0658
# Epoch 48/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6471 - root_mean_squared_error: 0.8334 - val_loss: 0.8720 - val_root_mean_squared_error: 1.0786
# Epoch 49/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6412 - root_mean_squared_error: 0.8283 - val_loss: 0.8638 - val_root_mean_squared_error: 1.0670
# Epoch 50/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6435 - root_mean_squared_error: 0.8344 - val_loss: 0.8621 - val_root_mean_squared_error: 1.0654
# Epoch 51/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6365 - root_mean_squared_error: 0.8225 - val_loss: 0.8679 - val_root_mean_squared_error: 1.0722
# Epoch 52/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6355 - root_mean_squared_error: 0.8226 - val_loss: 0.8684 - val_root_mean_squared_error: 1.0735
# Epoch 53/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6320 - root_mean_squared_error: 0.8174 - val_loss: 0.8768 - val_root_mean_squared_error: 1.0831
# Epoch 54/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6303 - root_mean_squared_error: 0.8185 - val_loss: 0.8687 - val_root_mean_squared_error: 1.0725
# Epoch 55/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6294 - root_mean_squared_error: 0.8135 - val_loss: 0.8735 - val_root_mean_squared_error: 1.0775
# Epoch 56/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6300 - root_mean_squared_error: 0.8130 - val_loss: 0.8831 - val_root_mean_squared_error: 1.0916
# Epoch 57/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6315 - root_mean_squared_error: 0.8149 - val_loss: 0.8777 - val_root_mean_squared_error: 1.0839
# Epoch 58/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6315 - root_mean_squared_error: 0.8205 - val_loss: 0.8890 - val_root_mean_squared_error: 1.0976
# Epoch 59/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6194 - root_mean_squared_error: 0.8022 - val_loss: 0.8875 - val_root_mean_squared_error: 1.0962
# Epoch 60/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6263 - root_mean_squared_error: 0.8133 - val_loss: 0.8901 - val_root_mean_squared_error: 1.1013
# Epoch 61/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6223 - root_mean_squared_error: 0.8083 - val_loss: 0.8821 - val_root_mean_squared_error: 1.0904
# Epoch 62/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.6249 - root_mean_squared_error: 0.8124 - val_loss: 0.8850 - val_root_mean_squared_error: 1.0953
# Epoch 63/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.6230 - root_mean_squared_error: 0.8109 - val_loss: 0.8884 - val_root_mean_squared_error: 1.0997
# Epoch 64/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6211 - root_mean_squared_error: 0.8101 - val_loss: 0.8947 - val_root_mean_squared_error: 1.1080
# Epoch 65/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6222 - root_mean_squared_error: 0.8082 - val_loss: 0.8965 - val_root_mean_squared_error: 1.1110
# Epoch 66/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6179 - root_mean_squared_error: 0.8041 - val_loss: 0.8912 - val_root_mean_squared_error: 1.1034
# Epoch 67/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6153 - root_mean_squared_error: 0.8055 - val_loss: 0.8914 - val_root_mean_squared_error: 1.1045
# Epoch 68/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6108 - root_mean_squared_error: 0.7966 - val_loss: 0.9002 - val_root_mean_squared_error: 1.1163
# Epoch 69/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6092 - root_mean_squared_error: 0.7975 - val_loss: 0.8915 - val_root_mean_squared_error: 1.1043
# Epoch 70/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6167 - root_mean_squared_error: 0.8078 - val_loss: 0.8996 - val_root_mean_squared_error: 1.1152
# Epoch 71/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6113 - root_mean_squared_error: 0.7987 - val_loss: 0.8943 - val_root_mean_squared_error: 1.1092
# Epoch 72/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6091 - root_mean_squared_error: 0.7970 - val_loss: 0.8963 - val_root_mean_squared_error: 1.1125
# Epoch 73/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6142 - root_mean_squared_error: 0.8066 - val_loss: 0.9041 - val_root_mean_squared_error: 1.1238
# Epoch 74/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6132 - root_mean_squared_error: 0.8062 - val_loss: 0.9068 - val_root_mean_squared_error: 1.1270
# Epoch 75/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6136 - root_mean_squared_error: 0.8076 - val_loss: 0.8913 - val_root_mean_squared_error: 1.1050
# Epoch 76/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6026 - root_mean_squared_error: 0.7937 - val_loss: 0.8935 - val_root_mean_squared_error: 1.1093
# Epoch 77/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6038 - root_mean_squared_error: 0.7930 - val_loss: 0.8964 - val_root_mean_squared_error: 1.1133
# Epoch 78/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6127 - root_mean_squared_error: 0.8018 - val_loss: 0.9020 - val_root_mean_squared_error: 1.1211
# Epoch 79/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6115 - root_mean_squared_error: 0.7996 - val_loss: 0.9053 - val_root_mean_squared_error: 1.1259
# Epoch 80/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6064 - root_mean_squared_error: 0.7973 - val_loss: 0.9049 - val_root_mean_squared_error: 1.1257
# Epoch 81/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6045 - root_mean_squared_error: 0.7978 - val_loss: 0.8892 - val_root_mean_squared_error: 1.1039
# Epoch 82/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6023 - root_mean_squared_error: 0.7905 - val_loss: 0.8975 - val_root_mean_squared_error: 1.1158
# Epoch 83/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5980 - root_mean_squared_error: 0.7872 - val_loss: 0.9010 - val_root_mean_squared_error: 1.1194
# Epoch 84/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6074 - root_mean_squared_error: 0.8018 - val_loss: 0.9087 - val_root_mean_squared_error: 1.1297
# Epoch 85/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6048 - root_mean_squared_error: 0.7966 - val_loss: 0.9024 - val_root_mean_squared_error: 1.1229
# Epoch 86/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6032 - root_mean_squared_error: 0.7943 - val_loss: 0.9042 - val_root_mean_squared_error: 1.1231
# Epoch 87/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6059 - root_mean_squared_error: 0.7977 - val_loss: 0.9105 - val_root_mean_squared_error: 1.1338
# Epoch 88/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5976 - root_mean_squared_error: 0.7881 - val_loss: 0.9046 - val_root_mean_squared_error: 1.1238
# Epoch 89/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5968 - root_mean_squared_error: 0.7865 - val_loss: 0.9095 - val_root_mean_squared_error: 1.1333
# Epoch 90/100
# 88/88 [==============================] - 1s 6ms/step - loss: 0.5984 - root_mean_squared_error: 0.7891 - val_loss: 0.9061 - val_root_mean_squared_error: 1.1286
# Epoch 91/100
# 88/88 [==============================] - 1s 6ms/step - loss: 0.5953 - root_mean_squared_error: 0.7873 - val_loss: 0.9024 - val_root_mean_squared_error: 1.1240
# Epoch 92/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.5953 - root_mean_squared_error: 0.7878 - val_loss: 0.8983 - val_root_mean_squared_error: 1.1162
# Epoch 93/100
# 88/88 [==============================] - 1s 6ms/step - loss: 0.5920 - root_mean_squared_error: 0.7833 - val_loss: 0.9048 - val_root_mean_squared_error: 1.1259
# Epoch 94/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.5958 - root_mean_squared_error: 0.7858 - val_loss: 0.9033 - val_root_mean_squared_error: 1.1249
# Epoch 95/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5932 - root_mean_squared_error: 0.7850 - val_loss: 0.9075 - val_root_mean_squared_error: 1.1311
# Epoch 96/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5916 - root_mean_squared_error: 0.7832 - val_loss: 0.9037 - val_root_mean_squared_error: 1.1260
# Epoch 97/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5919 - root_mean_squared_error: 0.7864 - val_loss: 0.8979 - val_root_mean_squared_error: 1.1179
# Epoch 98/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5955 - root_mean_squared_error: 0.7869 - val_loss: 0.9062 - val_root_mean_squared_error: 1.1297
# Epoch 99/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5946 - root_mean_squared_error: 0.7918 - val_loss: 0.9010 - val_root_mean_squared_error: 1.1218
# Epoch 100/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5979 - root_mean_squared_error: 0.7911 - val_loss: 0.9110 - val_root_mean_squared_error: 1.1371
# 783/783 [==============================] - 1s 1ms/step - loss: 0.7743 - root_mean_squared_error: 0.9904
# Test acc: [0.7742986083030701, 0.9903976321220398]

# %%
# grab history
history = hist.history

fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)

plt.plot(history['loss'], lw=2, color='darkgoldenrod')
plt.plot(history['val_loss'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
#plt.ylim(0.5,0.7)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Loss');

ax = fig.add_subplot(1, 3, 2)

plt.plot(history['root_mean_squared_error'], lw=2, color='darkgoldenrod')
plt.plot(history['val_root_mean_squared_error'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
#plt.ylim(0.5,0.7)
ax.set_xlabel('Epochs', size=10)
ax.set_title('RMSE');

# %%
#
model = get_model()
model.summary()

callbacks = [
    keras.callbacks.ModelCheckpoint("binary_1gram.keras", save_best_only=True)
]
hist = model.fit(
    x=all_train_features_ds,
    y=all_train_targets_ds,
    validation_data = None,
    epochs=25,
    callbacks=callbacks
)

model = keras.models.load_model("binary_1gram.keras")
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 20000)]           0
# _________________________________________________________________
# dense_25 (Dense)             (None, 32)                640032
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 643,398
# Trainable params: 643,398
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 123/123 [==============================] - 1s 3ms/step - loss: 0.7934 - root_mean_squared_error: 1.0038
# Epoch 2/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7815 - root_mean_squared_error: 1.0024
# Epoch 3/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7695 - root_mean_squared_error: 0.9924
# Epoch 4/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7638 - root_mean_squared_error: 0.9926
# Epoch 5/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7571 - root_mean_squared_error: 0.9855
# Epoch 6/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7515 - root_mean_squared_error: 0.9816
# Epoch 7/25
# 123/123 [==============================] - 0s 4ms/step - loss: 0.7515 - root_mean_squared_error: 0.9802
# Epoch 8/25
# 123/123 [==============================] - 1s 4ms/step - loss: 0.7423 - root_mean_squared_error: 0.9702
# Epoch 9/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7461 - root_mean_squared_error: 0.9771
# Epoch 10/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7382 - root_mean_squared_error: 0.9680
# Epoch 11/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7395 - root_mean_squared_error: 0.9694
# Epoch 12/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7359 - root_mean_squared_error: 0.9649
# Epoch 13/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7370 - root_mean_squared_error: 0.9675
# Epoch 14/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7329 - root_mean_squared_error: 0.9619
# Epoch 15/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7356 - root_mean_squared_error: 0.9641
# Epoch 16/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7297 - root_mean_squared_error: 0.9566
# Epoch 17/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7294 - root_mean_squared_error: 0.9580
# Epoch 18/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7279 - root_mean_squared_error: 0.9559
# Epoch 19/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7256 - root_mean_squared_error: 0.9532
# Epoch 20/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7263 - root_mean_squared_error: 0.9543
# Epoch 21/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7206 - root_mean_squared_error: 0.9481
# Epoch 22/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7270 - root_mean_squared_error: 0.9549
# Epoch 23/25
# 123/123 [==============================] - 1s 5ms/step - loss: 0.7231 - root_mean_squared_error: 0.9497
# Epoch 24/25
# 123/123 [==============================] - 1s 4ms/step - loss: 0.7230 - root_mean_squared_error: 0.9477
# Epoch 25/25
# 123/123 [==============================] - 0s 4ms/step - loss: 0.7216 - root_mean_squared_error: 0.9453

# %% [markdown]
# ## Submission to contest

# %%
test_predictions = model.predict(all_test_features_ds)
test_predictions = pd.DataFrame(all_sc_y.inverse_transform(test_predictions))

test_from_comp['cohesion'] = test_predictions[0]
test_from_comp['syntax'] = test_predictions[1]
test_from_comp['vocabulary'] = test_predictions[2]
test_from_comp['phraseology'] = test_predictions[3]
test_from_comp['grammar'] = test_predictions[4]
test_from_comp['conventions'] = test_predictions[5]
test_from_comp
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0000C359D63E  when a person has no experience on a job their...  2.996773
# 1  000BAD50D026  Do you think students would benefit from being...  2.733715
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...  3.377945
#
#      syntax  vocabulary  phraseology   grammar  conventions
# 0  2.995332    2.991596     3.000904  3.000585     2.992500
# 1  2.677618    2.831613     2.717005  2.662896     2.697914
# 2  3.336494    3.426062     3.398558  3.369525     3.355836

# %%
res = test_from_comp.drop("full_text",axis=1)
res.to_csv("/kaggle/working/submission.csv",index=False)
