# %% [markdown]
# <a href="https://www.kaggle.com/code/joeroberts/model-binary-2gram?scriptVersionId=112864415" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd 
from sklearn.preprocessing import StandardScaler

from transformers import BertTokenizer

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import GlobalAveragePooling1D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import GlobalAveragePooling1D
from tensorflow import keras
from tensorflow.keras import layers

# plots and images
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image

#sklearn processing
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split



import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

#configs
max_tokens = 20000
# Out:
# /kaggle/input/feedback-prize-english-language-learning/sample_submission.csv
# /kaggle/input/feedback-prize-english-language-learning/train.csv
# /kaggle/input/feedback-prize-english-language-learning/test.csv

# %%
sample_submission_raw = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/sample_submission.csv')
train_data_raw = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/train.csv')
test_from_comp = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/test.csv')

# %%
train, test = train_test_split(train_data_raw, test_size=0.2, random_state=21) #20% for test
train, val = train_test_split(train, test_size=0.1, random_state=21) # 10% for validation
train

targets=['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']

train_targets = train[targets]
val_targets = val[targets]
test_targets = test[targets]

train_targets_ds = tf.convert_to_tensor(train_targets)
val_targets_ds = tf.convert_to_tensor(val_targets)
test_targets_ds = tf.convert_to_tensor(test_targets)

train_text_only = tf.convert_to_tensor(train['full_text'])
val_text_only = tf.convert_to_tensor(val['full_text'])
test_text_only = tf.convert_to_tensor(test['full_text'])


## for submission 
all_train_targets = train_data_raw[targets]
all_train_targets_ds = tf.convert_to_tensor(all_train_targets)
all_train_text_only = tf.convert_to_tensor(train_data_raw['full_text'])
all_test_text_only = tf.convert_to_tensor(test_from_comp['full_text'])

# %%
text_vectorization = layers.TextVectorization(
    ngrams=2,
    max_tokens=max_tokens,
    output_mode="multi_hot",
)

#use the dataset to index the dataset vocab via the adapt method
text_vectorization.adapt(train_text_only)

train_features_ds = text_vectorization(train_text_only)
val_features_ds = text_vectorization(val_text_only)
test_features_ds = text_vectorization(test_text_only)

#for submission
all_train_features_ds = text_vectorization(all_train_text_only)
all_test_features_ds = text_vectorization(all_test_text_only)

# %%
def get_model(max_tokens=max_tokens, hidden_dim=32):
    inputs = keras.Input(shape=(max_tokens,))

    x = layers.Dense(hidden_dim, activation="relu")(inputs)
    x = layers.Dropout(rate=0.5)(x)
    
    x = layers.Dense(hidden_dim, activation="relu")(x)
    x = layers.Dropout(rate=0.5)(x)
    
    x = layers.Dense(hidden_dim, activation="relu")(x)
    x = layers.Dropout(rate=0.5)(x)


    outputs = layers.Dense(6, activation=None)(x)
    
    model = keras.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss="mean_absolute_error",
        metrics=[tf.keras.metrics.RootMeanSquaredError(
                name='root_mean_squared_error', dtype=None
            )]
    )
    return model

#train model and test
model = get_model()
model.summary()

callbacks = [
    keras.callbacks.ModelCheckpoint("binary_2gram.keras", save_best_only=True)
]
hist = model.fit(
    x=train_features_ds,
    y=train_targets_ds,
    validation_data = (
        val_features_ds, val_targets_ds
    ),
    epochs=30,
    callbacks=callbacks
)

model = keras.models.load_model("binary_2gram.keras")
print(f"Test acc: {model.evaluate(test_features_ds, test_targets_ds, 1)}")
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 20000)]           0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                640032
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 642,342
# Trainable params: 642,342
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 88/88 [==============================] - 1s 5ms/step - loss: 2.0060 - root_mean_squared_error: 2.4006 - val_loss: 1.4135 - val_root_mean_squared_error: 1.5497
# Epoch 2/30
# 88/88 [==============================] - 0s 4ms/step - loss: 1.4556 - root_mean_squared_error: 1.7927 - val_loss: 1.3917 - val_root_mean_squared_error: 1.5317
# Epoch 3/30
# 88/88 [==============================] - 0s 5ms/step - loss: 1.2553 - root_mean_squared_error: 1.5596 - val_loss: 1.1801 - val_root_mean_squared_error: 1.3380
# Epoch 4/30
# 88/88 [==============================] - 0s 4ms/step - loss: 1.1018 - root_mean_squared_error: 1.3756 - val_loss: 1.0010 - val_root_mean_squared_error: 1.1721
# Epoch 5/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.9282 - root_mean_squared_error: 1.1783 - val_loss: 0.6454 - val_root_mean_squared_error: 0.7944
# Epoch 6/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.8126 - root_mean_squared_error: 1.0204 - val_loss: 0.5984 - val_root_mean_squared_error: 0.7396
# Epoch 7/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7806 - root_mean_squared_error: 0.9861 - val_loss: 0.5848 - val_root_mean_squared_error: 0.7254
# Epoch 8/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7543 - root_mean_squared_error: 0.9435 - val_loss: 0.5800 - val_root_mean_squared_error: 0.7212
# Epoch 9/30
# 88/88 [==============================] - 0s 3ms/step - loss: 0.7290 - root_mean_squared_error: 0.9200 - val_loss: 0.5844 - val_root_mean_squared_error: 0.7248
# Epoch 10/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7289 - root_mean_squared_error: 0.9162 - val_loss: 0.5815 - val_root_mean_squared_error: 0.7229
# Epoch 11/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7154 - root_mean_squared_error: 0.8952 - val_loss: 0.5723 - val_root_mean_squared_error: 0.7128
# Epoch 12/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6999 - root_mean_squared_error: 0.8792 - val_loss: 0.5746 - val_root_mean_squared_error: 0.7140
# Epoch 13/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6862 - root_mean_squared_error: 0.8617 - val_loss: 0.5794 - val_root_mean_squared_error: 0.7196
# Epoch 14/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6878 - root_mean_squared_error: 0.8604 - val_loss: 0.5610 - val_root_mean_squared_error: 0.7008
# Epoch 15/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6743 - root_mean_squared_error: 0.8463 - val_loss: 0.5463 - val_root_mean_squared_error: 0.6805
# Epoch 16/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6542 - root_mean_squared_error: 0.8202 - val_loss: 0.5364 - val_root_mean_squared_error: 0.6689
# Epoch 17/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6582 - root_mean_squared_error: 0.8287 - val_loss: 0.5405 - val_root_mean_squared_error: 0.6773
# Epoch 18/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6433 - root_mean_squared_error: 0.8079 - val_loss: 0.5554 - val_root_mean_squared_error: 0.6890
# Epoch 19/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6468 - root_mean_squared_error: 0.8099 - val_loss: 0.5423 - val_root_mean_squared_error: 0.6763
# Epoch 20/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6206 - root_mean_squared_error: 0.7794 - val_loss: 0.5300 - val_root_mean_squared_error: 0.6620
# Epoch 21/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6268 - root_mean_squared_error: 0.7886 - val_loss: 0.5428 - val_root_mean_squared_error: 0.6749
# Epoch 22/30
# 88/88 [==============================] - 0s 5ms/step - loss: 0.6203 - root_mean_squared_error: 0.7740 - val_loss: 0.5370 - val_root_mean_squared_error: 0.6706
# Epoch 23/30
# 88/88 [==============================] - 0s 5ms/step - loss: 0.6080 - root_mean_squared_error: 0.7652 - val_loss: 0.5277 - val_root_mean_squared_error: 0.6591
# Epoch 24/30
# 88/88 [==============================] - 0s 6ms/step - loss: 0.6054 - root_mean_squared_error: 0.7574 - val_loss: 0.5383 - val_root_mean_squared_error: 0.6693
# Epoch 25/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6098 - root_mean_squared_error: 0.7686 - val_loss: 0.5295 - val_root_mean_squared_error: 0.6568
# Epoch 26/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6029 - root_mean_squared_error: 0.7585 - val_loss: 0.5171 - val_root_mean_squared_error: 0.6427
# Epoch 27/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5984 - root_mean_squared_error: 0.7502 - val_loss: 0.5340 - val_root_mean_squared_error: 0.6631
# Epoch 28/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5884 - root_mean_squared_error: 0.7385 - val_loss: 0.5198 - val_root_mean_squared_error: 0.6481
# Epoch 29/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5823 - root_mean_squared_error: 0.7296 - val_loss: 0.5212 - val_root_mean_squared_error: 0.6494
# Epoch 30/30
# 88/88 [==============================] - 0s 4ms/step - loss: 0.5853 - root_mean_squared_error: 0.7348 - val_loss: 0.5204 - val_root_mean_squared_error: 0.6478
# 783/783 [==============================] - 1s 2ms/step - loss: 0.4895 - root_mean_squared_error: 0.6177
# Test acc: [0.4895419478416443, 0.617725670337677]

# %%
# grab history
history = hist.history

fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)

plt.plot(history['loss'], lw=2, color='darkgoldenrod')
plt.plot(history['val_loss'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
#plt.ylim(0.5,0.7)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Loss');

ax = fig.add_subplot(1, 3, 2)

plt.plot(history['root_mean_squared_error'], lw=2, color='darkgoldenrod')
plt.plot(history['val_root_mean_squared_error'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
#plt.ylim(0.5,0.7)
ax.set_xlabel('Epochs', size=10)
ax.set_title('RMSE');

# %%
#
model = get_model()
model.summary()

callbacks = [
    keras.callbacks.ModelCheckpoint("binary_1gram.keras", save_best_only=True)
]
hist = model.fit(
    x=all_train_features_ds,
    y=all_train_targets_ds,
    validation_data = None,
    epochs=30,
    callbacks=callbacks
)

#model = keras.models.load_model("binary_1gram.keras")
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 20000)]           0
# _________________________________________________________________
# dense_16 (Dense)             (None, 32)                640032
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 642,342
# Trainable params: 642,342
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 123/123 [==============================] - 1s 3ms/step - loss: 2.0911 - root_mean_squared_error: 2.4628
# Epoch 2/25
# 123/123 [==============================] - 0s 3ms/step - loss: 1.3863 - root_mean_squared_error: 1.7032
# Epoch 3/25
# 123/123 [==============================] - 0s 3ms/step - loss: 1.0867 - root_mean_squared_error: 1.3814
# Epoch 4/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.8818 - root_mean_squared_error: 1.1091
# Epoch 5/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.8370 - root_mean_squared_error: 1.0616
# Epoch 6/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.8057 - root_mean_squared_error: 1.0288
# Epoch 7/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7649 - root_mean_squared_error: 0.9624
# Epoch 8/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7302 - root_mean_squared_error: 0.9196
# Epoch 9/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7272 - root_mean_squared_error: 0.9117
# Epoch 10/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7001 - root_mean_squared_error: 0.8790
# Epoch 11/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6949 - root_mean_squared_error: 0.8698
# Epoch 12/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6727 - root_mean_squared_error: 0.8430
# Epoch 13/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6820 - root_mean_squared_error: 0.8506
# Epoch 14/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6603 - root_mean_squared_error: 0.8281
# Epoch 15/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6525 - root_mean_squared_error: 0.8176
# Epoch 16/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6490 - root_mean_squared_error: 0.8158
# Epoch 17/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6355 - root_mean_squared_error: 0.7945
# Epoch 18/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6415 - root_mean_squared_error: 0.7994
# Epoch 19/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6355 - root_mean_squared_error: 0.7978
# Epoch 20/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6224 - root_mean_squared_error: 0.7778
# Epoch 21/25
# 123/123 [==============================] - 1s 4ms/step - loss: 0.6133 - root_mean_squared_error: 0.7676
# Epoch 22/25
# 123/123 [==============================] - 1s 4ms/step - loss: 0.6093 - root_mean_squared_error: 0.7642
# Epoch 23/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.5857 - root_mean_squared_error: 0.7367
# Epoch 24/25
# 123/123 [==============================] - 0s 4ms/step - loss: 0.5795 - root_mean_squared_error: 0.7325
# Epoch 25/25
# 123/123 [==============================] - 1s 5ms/step - loss: 0.5641 - root_mean_squared_error: 0.7088

# %% [markdown]
# ## Submission to contest

# %%
test_predictions = model.predict(all_test_features_ds)
test_predictions = pd.DataFrame(test_predictions)

test_from_comp['cohesion'] = test_predictions[0]
test_from_comp['syntax'] = test_predictions[1]
test_from_comp['vocabulary'] = test_predictions[2]
test_from_comp['phraseology'] = test_predictions[3]
test_from_comp['grammar'] = test_predictions[4]
test_from_comp['conventions'] = test_predictions[5]
test_from_comp
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0000C359D63E  when a person has no experience on a job their...  2.848269
# 1  000BAD50D026  Do you think students would benefit from being...  2.954489
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...  3.107044
#
#      syntax  vocabulary  phraseology   grammar  conventions
# 0  2.752156    2.943278     2.843483  2.720756     2.803386
# 1  2.842933    3.041076     2.953503  2.824872     2.899711
# 2  2.982221    3.194468     3.100437  2.973673     3.042013

# %%
res = test_from_comp.drop("full_text",axis=1)
res.to_csv("/kaggle/working/submission.csv",index=False)
