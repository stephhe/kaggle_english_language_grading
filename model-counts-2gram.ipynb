# %%
import numpy as np
import pandas as pd 
from sklearn.preprocessing import StandardScaler

from transformers import BertTokenizer

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import GlobalAveragePooling1D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import GlobalAveragePooling1D
from tensorflow import keras
from tensorflow.keras import layers

# plots and images
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image

#sklearn processing
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split



import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

#configs
max_tokens = 20000
# Out:
# /kaggle/input/feedback-prize-english-language-learning/sample_submission.csv
# /kaggle/input/feedback-prize-english-language-learning/train.csv
# /kaggle/input/feedback-prize-english-language-learning/test.csv

# %%
sample_submission_raw = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/sample_submission.csv')
train_data_raw = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/train.csv')
test_from_comp = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/test.csv')

# %%
train, test = train_test_split(train_data_raw, test_size=0.2, random_state=21) #20% for test
train, val = train_test_split(train, test_size=0.1, random_state=21) # 10% for validation
train

targets=['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']

sc_y = StandardScaler()
train_targets = sc_y.fit_transform(train[targets])
val_targets = sc_y.transform(val[targets])
test_targets = sc_y.transform(test[targets])

train_targets_ds = tf.convert_to_tensor(train_targets)
val_targets_ds = tf.convert_to_tensor(val_targets)
test_targets_ds = tf.convert_to_tensor(test_targets)

train_text_only = tf.convert_to_tensor(train['full_text'])
val_text_only = tf.convert_to_tensor(val['full_text'])
test_text_only = tf.convert_to_tensor(test['full_text'])


## for submission 
all_sc_y = StandardScaler()
all_train_targets = all_sc_y.fit_transform(train_data_raw[targets])
all_train_targets_ds = tf.convert_to_tensor(all_train_targets)
all_train_text_only = tf.convert_to_tensor(train_data_raw['full_text'])

all_test_text_only = tf.convert_to_tensor(test_from_comp['full_text'])
# Out:
# 2022-11-26 20:11:57.597124: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-26 20:11:57.688997: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-26 20:11:57.689789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-26 20:11:57.692708: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-26 20:11:57.693029: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-26 20:11:57.693781: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-26 20:11:57.694484: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-26 20:11:59.899342: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-26 20:11:59.900219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-26 20:11:59.900898: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-26 20:11:59.901504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
# text_vectorization = layers.TextVectorization(
#     max_tokens=max_tokens,
#     output_mode="multi_hot"
# )

text_vectorization = layers.TextVectorization(
    ngrams=2,
    max_tokens=max_tokens,
    output_mode="count",
)

#use the dataset to index the dataset vocab via the adapt method
text_vectorization.adapt(train_text_only)

train_features_ds = text_vectorization(train_text_only)
val_features_ds = text_vectorization(val_text_only)
test_features_ds = text_vectorization(test_text_only)

#for submission
all_train_features_ds = text_vectorization(all_train_text_only)
all_test_features_ds = text_vectorization(all_test_text_only)
# Out:
# 2022-11-26 20:12:00.379994: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
def get_model(max_tokens=max_tokens, hidden_dim=32):
    
    inputs = keras.Input(shape=(max_tokens,))
    
    x = layers.LayerNormalization()(inputs)
    
    x = layers.Dense(hidden_dim, activation="relu")(inputs)
    x = layers.Dropout(rate=0.5)(x)
    
    x = layers.Dense(hidden_dim, activation="relu")(x)
    x = layers.Dropout(rate=0.5)(x)
    
    x = layers.Dense(hidden_dim, activation="relu")(x)
    x = layers.Dropout(rate=0.5)(x)


    outputs = layers.Dense(6, activation=None)(x)
    
    model = keras.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss="mean_absolute_error",
        metrics=[tf.keras.metrics.RootMeanSquaredError(
                name='root_mean_squared_error', dtype=None
            )]
    )
    return model

#train model and test
model = get_model()
model.summary()

callbacks = [
    keras.callbacks.ModelCheckpoint("counts_2gram.keras", save_best_only=True)
]
hist = model.fit(
    x=train_features_ds,
    y=train_targets_ds,
    validation_data = (
        val_features_ds, val_targets_ds
    ),
    epochs=25,
    callbacks=callbacks
)

model = keras.models.load_model("counts_2gram.keras")
print(f"Test acc: {model.evaluate(test_features_ds, test_targets_ds, 1)}")
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 20000)]           0
# _________________________________________________________________
# dense_24 (Dense)             (None, 32)                640032
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_25 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 642,342
# Trainable params: 642,342
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 88/88 [==============================] - 1s 5ms/step - loss: 0.8252 - root_mean_squared_error: 1.0683 - val_loss: 0.8476 - val_root_mean_squared_error: 1.0556
# Epoch 2/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7881 - root_mean_squared_error: 1.0043 - val_loss: 0.8420 - val_root_mean_squared_error: 1.0581
# Epoch 3/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7830 - root_mean_squared_error: 1.0066 - val_loss: 0.8392 - val_root_mean_squared_error: 1.0611
# Epoch 4/25
# 88/88 [==============================] - 0s 5ms/step - loss: 0.7801 - root_mean_squared_error: 1.0083 - val_loss: 0.8374 - val_root_mean_squared_error: 1.0631
# Epoch 5/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7784 - root_mean_squared_error: 1.0103 - val_loss: 0.8365 - val_root_mean_squared_error: 1.0645
# Epoch 6/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7784 - root_mean_squared_error: 1.0144 - val_loss: 0.8359 - val_root_mean_squared_error: 1.0658
# Epoch 7/25
# 88/88 [==============================] - 0s 5ms/step - loss: 0.7774 - root_mean_squared_error: 1.0139 - val_loss: 0.8352 - val_root_mean_squared_error: 1.0675
# Epoch 8/25
# 88/88 [==============================] - 0s 5ms/step - loss: 0.7765 - root_mean_squared_error: 1.0149 - val_loss: 0.8347 - val_root_mean_squared_error: 1.0693
# Epoch 9/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7759 - root_mean_squared_error: 1.0172 - val_loss: 0.8341 - val_root_mean_squared_error: 1.0712
# Epoch 10/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7753 - root_mean_squared_error: 1.0194 - val_loss: 0.8334 - val_root_mean_squared_error: 1.0735
# Epoch 11/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7747 - root_mean_squared_error: 1.0215 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0749
# Epoch 12/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7747 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0750
# Epoch 13/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0750
# Epoch 14/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0750
# Epoch 15/25
# 88/88 [==============================] - 0s 3ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0749
# Epoch 16/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0750
# Epoch 17/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0749
# Epoch 18/25
# 88/88 [==============================] - 0s 3ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0749
# Epoch 19/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0750
# Epoch 20/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0749
# Epoch 21/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0749
# Epoch 22/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0750
# Epoch 23/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0749
# Epoch 24/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0749
# Epoch 25/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7746 - root_mean_squared_error: 1.0220 - val_loss: 0.8331 - val_root_mean_squared_error: 1.0750
# 783/783 [==============================] - 1s 1ms/step - loss: 0.7759 - root_mean_squared_error: 1.0231
# Test acc: [0.7758912444114685, 1.0231428146362305]

# %%
# grab history
history = hist.history

fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)

plt.plot(history['loss'], lw=2, color='darkgoldenrod')
plt.plot(history['val_loss'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
#plt.ylim(0.5,0.7)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Loss');

ax = fig.add_subplot(1, 3, 2)

plt.plot(history['root_mean_squared_error'], lw=2, color='darkgoldenrod')
plt.plot(history['val_root_mean_squared_error'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
#plt.ylim(0.5,0.7)
ax.set_xlabel('Epochs', size=10)
ax.set_title('RMSE');

# %%
#
model = get_model()
model.summary()

callbacks = [
    keras.callbacks.ModelCheckpoint("counts_2gram.keras", save_best_only=True)
]
hist = model.fit(
    x=all_train_features_ds,
    y=all_train_targets_ds,
    validation_data = None,
    epochs=25,
    callbacks=callbacks
)

model = keras.models.load_model("counts_2gram.keras")
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 20000)]           0
# _________________________________________________________________
# dense_28 (Dense)             (None, 32)                640032
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_30 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_31 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 642,342
# Trainable params: 642,342
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 123/123 [==============================] - 1s 3ms/step - loss: 0.8057 - root_mean_squared_error: 1.0303
# Epoch 2/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7839 - root_mean_squared_error: 1.0058
# Epoch 3/25
# 123/123 [==============================] - 1s 5ms/step - loss: 0.7808 - root_mean_squared_error: 1.0090
# Epoch 4/25
# 123/123 [==============================] - 0s 4ms/step - loss: 0.7786 - root_mean_squared_error: 1.0111
# Epoch 5/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7773 - root_mean_squared_error: 1.0138
# Epoch 6/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7761 - root_mean_squared_error: 1.0172
# Epoch 7/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7751 - root_mean_squared_error: 1.0207
# Epoch 8/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7749 - root_mean_squared_error: 1.0206
# Epoch 9/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7748 - root_mean_squared_error: 1.0204
# Epoch 10/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7747 - root_mean_squared_error: 1.0204
# Epoch 11/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7748 - root_mean_squared_error: 1.0204
# Epoch 12/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7746 - root_mean_squared_error: 1.0201
# Epoch 13/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7750 - root_mean_squared_error: 1.0208
# Epoch 14/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7750 - root_mean_squared_error: 1.0206
# Epoch 15/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7746 - root_mean_squared_error: 1.0201
# Epoch 16/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7750 - root_mean_squared_error: 1.0206
# Epoch 17/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7751 - root_mean_squared_error: 1.0207
# Epoch 18/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7749 - root_mean_squared_error: 1.0209
# Epoch 19/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7750 - root_mean_squared_error: 1.0206
# Epoch 20/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7750 - root_mean_squared_error: 1.0206
# Epoch 21/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7750 - root_mean_squared_error: 1.0206
# Epoch 22/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7750 - root_mean_squared_error: 1.0206
# Epoch 23/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7750 - root_mean_squared_error: 1.0206
# Epoch 24/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7750 - root_mean_squared_error: 1.0206
# Epoch 25/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7750 - root_mean_squared_error: 1.0206

# %% [markdown]
# ## Submission to contest

# %%
test_predictions = model.predict(all_test_features_ds)
test_predictions = pd.DataFrame(all_sc_y.inverse_transform(test_predictions))

test_from_comp['cohesion'] = test_predictions[0]
test_from_comp['syntax'] = test_predictions[1]
test_from_comp['vocabulary'] = test_predictions[2]
test_from_comp['phraseology'] = test_predictions[3]
test_from_comp['grammar'] = test_predictions[4]
test_from_comp['conventions'] = test_predictions[5]
test_from_comp
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0000C359D63E  when a person has no experience on a job their...  2.996161
# 1  000BAD50D026  Do you think students would benefit from being...  2.996161
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...  2.996161
#
#      syntax  vocabulary  phraseology   grammar  conventions
# 0  2.995569      2.9916     3.000859  3.000494     2.993745
# 1  2.995569      2.9916     3.000859  3.000494     2.993745
# 2  2.995569      2.9916     3.000859  3.000494     2.993745

# %%
res = test_from_comp.drop("full_text",axis=1)
res.to_csv("/kaggle/working/submission.csv",index=False)
