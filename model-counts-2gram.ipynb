# %% [markdown]
# <a href="https://www.kaggle.com/code/joeroberts/model-counts-2gram?scriptVersionId=112865355" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd 
from sklearn.preprocessing import StandardScaler

from transformers import BertTokenizer

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import GlobalAveragePooling1D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import GlobalAveragePooling1D
from tensorflow import keras
from tensorflow.keras import layers

# plots and images
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image

#sklearn processing
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split



import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

#configs
max_tokens = 20000
# Out:
# /kaggle/input/feedback-prize-english-language-learning/sample_submission.csv
# /kaggle/input/feedback-prize-english-language-learning/train.csv
# /kaggle/input/feedback-prize-english-language-learning/test.csv

# %%
sample_submission_raw = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/sample_submission.csv')
train_data_raw = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/train.csv')
test_from_comp = pd.read_csv('/kaggle/input/feedback-prize-english-language-learning/test.csv')

# %%
train, test = train_test_split(train_data_raw, test_size=0.2, random_state=21) #20% for test
train, val = train_test_split(train, test_size=0.1, random_state=21) # 10% for validation
train

targets=['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']

sc_y = StandardScaler()
train_targets = train[targets]
val_targets = val[targets]
test_targets = test[targets]

train_targets_ds = tf.convert_to_tensor(train_targets)
val_targets_ds = tf.convert_to_tensor(val_targets)
test_targets_ds = tf.convert_to_tensor(test_targets)

train_text_only = tf.convert_to_tensor(train['full_text'])
val_text_only = tf.convert_to_tensor(val['full_text'])
test_text_only = tf.convert_to_tensor(test['full_text'])


## for submission 
all_train_targets = train_data_raw[targets]
all_train_targets_ds = tf.convert_to_tensor(all_train_targets)
all_train_text_only = tf.convert_to_tensor(train_data_raw['full_text'])

all_test_text_only = tf.convert_to_tensor(test_from_comp['full_text'])

# %%
# text_vectorization = layers.TextVectorization(
#     max_tokens=max_tokens,
#     output_mode="multi_hot"
# )

text_vectorization = layers.TextVectorization(
    ngrams=2,
    max_tokens=max_tokens,
    output_mode="count",
)

#use the dataset to index the dataset vocab via the adapt method
text_vectorization.adapt(train_text_only)

train_features_ds = text_vectorization(train_text_only)
val_features_ds = text_vectorization(val_text_only)
test_features_ds = text_vectorization(test_text_only)

#for submission
all_train_features_ds = text_vectorization(all_train_text_only)
all_test_features_ds = text_vectorization(all_test_text_only)

# %%
def get_model(max_tokens=max_tokens, hidden_dim=32):
    
    inputs = keras.Input(shape=(max_tokens,))
    
    x = layers.LayerNormalization()(inputs)
    
    x = layers.Dense(hidden_dim, activation="relu")(inputs)
    x = layers.Dropout(rate=0.5)(x)
    
    x = layers.Dense(hidden_dim, activation="relu")(x)
    x = layers.Dropout(rate=0.5)(x)
    
    x = layers.Dense(hidden_dim, activation="relu")(x)
    x = layers.Dropout(rate=0.5)(x)


    outputs = layers.Dense(6, activation=None)(x)
    
    model = keras.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss="mean_absolute_error",
        metrics=[tf.keras.metrics.RootMeanSquaredError(
                name='root_mean_squared_error', dtype=None
            )]
    )
    return model

#train model and test
model = get_model()
model.summary()

callbacks = [
    keras.callbacks.ModelCheckpoint("counts_2gram.keras", save_best_only=True)
]
hist = model.fit(
    x=train_features_ds,
    y=train_targets_ds,
    validation_data = (
        val_features_ds, val_targets_ds
    ),
    epochs=25,
    callbacks=callbacks
)

model = keras.models.load_model("counts_2gram.keras")
print(f"Test acc: {model.evaluate(test_features_ds, test_targets_ds, 1)}")
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 20000)]           0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                640032
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 642,342
# Trainable params: 642,342
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 88/88 [==============================] - 1s 7ms/step - loss: 2.2555 - root_mean_squared_error: 2.6875 - val_loss: 1.4292 - val_root_mean_squared_error: 1.6017
# Epoch 2/25
# 88/88 [==============================] - 0s 4ms/step - loss: 1.6565 - root_mean_squared_error: 2.0334 - val_loss: 1.3207 - val_root_mean_squared_error: 1.4727
# Epoch 3/25
# 88/88 [==============================] - 0s 4ms/step - loss: 1.2354 - root_mean_squared_error: 1.5508 - val_loss: 0.6660 - val_root_mean_squared_error: 0.8355
# Epoch 4/25
# 88/88 [==============================] - 0s 3ms/step - loss: 0.9101 - root_mean_squared_error: 1.1535 - val_loss: 0.5949 - val_root_mean_squared_error: 0.7368
# Epoch 5/25
# 88/88 [==============================] - 0s 6ms/step - loss: 0.8280 - root_mean_squared_error: 1.0427 - val_loss: 0.5702 - val_root_mean_squared_error: 0.7090
# Epoch 6/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7954 - root_mean_squared_error: 0.9944 - val_loss: 0.5851 - val_root_mean_squared_error: 0.7275
# Epoch 7/25
# 51/88 [================>.............] - ETA: 0s - loss: 0.7794 - root_mean_squared_error: 0.9844
# Exception ignored in: <function IteratorResourceDeleter.__del__ at 0x7f4b8792a560>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py", line 546, in __del__
#     handle=self._handle, deleter=self._deleter)
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gen_dataset_ops.py", line 1264, in delete_iterator
#     _ctx, "DeleteIterator", name, handle, deleter)
# KeyboardInterrupt:
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7662 - root_mean_squared_error: 0.9653 - val_loss: 0.5818 - val_root_mean_squared_error: 0.7218
# Epoch 8/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7476 - root_mean_squared_error: 0.9324 - val_loss: 0.5827 - val_root_mean_squared_error: 0.7237
# Epoch 9/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7307 - root_mean_squared_error: 0.9136 - val_loss: 0.5636 - val_root_mean_squared_error: 0.7023
# Epoch 10/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7181 - root_mean_squared_error: 0.8989 - val_loss: 0.5640 - val_root_mean_squared_error: 0.7055
# Epoch 11/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7108 - root_mean_squared_error: 0.8894 - val_loss: 0.5662 - val_root_mean_squared_error: 0.7077
# Epoch 12/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6899 - root_mean_squared_error: 0.8668 - val_loss: 0.5543 - val_root_mean_squared_error: 0.6922
# Epoch 13/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6959 - root_mean_squared_error: 0.8768 - val_loss: 0.5519 - val_root_mean_squared_error: 0.6949
# Epoch 14/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6651 - root_mean_squared_error: 0.8398 - val_loss: 0.5489 - val_root_mean_squared_error: 0.6870
# Epoch 15/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6695 - root_mean_squared_error: 0.8367 - val_loss: 0.5547 - val_root_mean_squared_error: 0.6959
# Epoch 16/25
# 88/88 [==============================] - 0s 3ms/step - loss: 0.6668 - root_mean_squared_error: 0.8390 - val_loss: 0.5552 - val_root_mean_squared_error: 0.6973
# Epoch 17/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6622 - root_mean_squared_error: 0.8308 - val_loss: 0.5529 - val_root_mean_squared_error: 0.6940
# Epoch 18/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6705 - root_mean_squared_error: 0.8350 - val_loss: 0.5488 - val_root_mean_squared_error: 0.6863
# Epoch 19/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6530 - root_mean_squared_error: 0.8151 - val_loss: 0.5533 - val_root_mean_squared_error: 0.6933
# Epoch 20/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6595 - root_mean_squared_error: 0.8258 - val_loss: 0.5507 - val_root_mean_squared_error: 0.6895
# Epoch 21/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6400 - root_mean_squared_error: 0.7992 - val_loss: 0.5522 - val_root_mean_squared_error: 0.6919
# Epoch 22/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6381 - root_mean_squared_error: 0.7937 - val_loss: 0.5497 - val_root_mean_squared_error: 0.6861
# Epoch 23/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6319 - root_mean_squared_error: 0.7900 - val_loss: 0.5501 - val_root_mean_squared_error: 0.6883
# Epoch 24/25
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6330 - root_mean_squared_error: 0.7928 - val_loss: 0.5524 - val_root_mean_squared_error: 0.6926
# Epoch 25/25
# 88/88 [==============================] - 0s 3ms/step - loss: 0.6273 - root_mean_squared_error: 0.7821 - val_loss: 0.5505 - val_root_mean_squared_error: 0.6920
# 783/783 [==============================] - 1s 1ms/step - loss: 0.5173 - root_mean_squared_error: 0.6556
# Test acc: [0.5173174142837524, 0.655616283416748]

# %%
# grab history
history = hist.history

fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)

plt.plot(history['loss'], lw=2, color='darkgoldenrod')
plt.plot(history['val_loss'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
#plt.ylim(0.5,0.7)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Loss');

ax = fig.add_subplot(1, 3, 2)

plt.plot(history['root_mean_squared_error'], lw=2, color='darkgoldenrod')
plt.plot(history['val_root_mean_squared_error'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
#plt.ylim(0.5,0.7)
ax.set_xlabel('Epochs', size=10)
ax.set_title('RMSE');

# %%
#
model = get_model()
model.summary()

callbacks = [
    keras.callbacks.ModelCheckpoint("counts_2gram.keras", save_best_only=True)
]
hist = model.fit(
    x=all_train_features_ds,
    y=all_train_targets_ds,
    validation_data = None,
    epochs=25,
    callbacks=callbacks
)
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 20000)]           0
# _________________________________________________________________
# dense_20 (Dense)             (None, 32)                640032
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 642,342
# Trainable params: 642,342
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 123/123 [==============================] - 1s 3ms/step - loss: 2.2070 - root_mean_squared_error: 2.6075
# Epoch 2/25
# 123/123 [==============================] - 0s 3ms/step - loss: 1.5287 - root_mean_squared_error: 1.8831
# Epoch 3/25
# 123/123 [==============================] - 0s 3ms/step - loss: 1.0132 - root_mean_squared_error: 1.2741
# Epoch 4/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.8923 - root_mean_squared_error: 1.1321
# Epoch 5/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.8313 - root_mean_squared_error: 1.0446
# Epoch 6/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7938 - root_mean_squared_error: 0.9895
# Epoch 7/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7632 - root_mean_squared_error: 0.9533
# Epoch 8/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7397 - root_mean_squared_error: 0.9330
# Epoch 9/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7288 - root_mean_squared_error: 0.9223
# Epoch 10/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7022 - root_mean_squared_error: 0.8796
# Epoch 11/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6917 - root_mean_squared_error: 0.8622
# Epoch 12/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6790 - root_mean_squared_error: 0.8514
# Epoch 13/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6658 - root_mean_squared_error: 0.8345
# Epoch 14/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6680 - root_mean_squared_error: 0.8370
# Epoch 15/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6565 - root_mean_squared_error: 0.8230
# Epoch 16/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6443 - root_mean_squared_error: 0.8070
# Epoch 17/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6493 - root_mean_squared_error: 0.8139
# Epoch 18/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6419 - root_mean_squared_error: 0.7986
# Epoch 19/25
# 123/123 [==============================] - 1s 4ms/step - loss: 0.6421 - root_mean_squared_error: 0.8039
# Epoch 20/25
# 123/123 [==============================] - 0s 4ms/step - loss: 0.6322 - root_mean_squared_error: 0.7933
# Epoch 21/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6255 - root_mean_squared_error: 0.7819
# Epoch 22/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6258 - root_mean_squared_error: 0.7831
# Epoch 23/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6198 - root_mean_squared_error: 0.7753
# Epoch 24/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6073 - root_mean_squared_error: 0.7569
# Epoch 25/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6148 - root_mean_squared_error: 0.7659

# %% [markdown]
# ## Submission to contest

# %%
test_predictions = model.predict(all_test_features_ds)
test_predictions = pd.DataFrame(test_predictions)

test_from_comp['cohesion'] = test_predictions[0]
test_from_comp['syntax'] = test_predictions[1]
test_from_comp['vocabulary'] = test_predictions[2]
test_from_comp['phraseology'] = test_predictions[3]
test_from_comp['grammar'] = test_predictions[4]
test_from_comp['conventions'] = test_predictions[5]
test_from_comp
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0000C359D63E  when a person has no experience on a job their...  3.060567
# 1  000BAD50D026  Do you think students would benefit from being...  3.060567
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...  3.060567
#
#      syntax  vocabulary  phraseology  grammar  conventions
# 0  2.956896     3.14746     3.064723  2.94527     3.034435
# 1  2.956896     3.14746     3.064723  2.94527     3.034435
# 2  2.956896     3.14746     3.064723  2.94527     3.034435

# %%
res = test_from_comp.drop("full_text",axis=1)
res.to_csv("/kaggle/working/submission.csv",index=False)
